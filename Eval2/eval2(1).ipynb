# %%
import pandas as pd

import numpy as np

import matplotlib as plt

# %matplotlib inline

# %%
df = pd.read_csv ("/home/lcoronado/computacional1/eval2/data.txt", sep="\s+", names=("año", "mes", "añodec", "manchas", "dato1", "dato2"))

# %%
df
# Out:
#        año  mes    añodec  manchas  dato1  dato2
# 0     1749    1  1749.042     96.7   -1.0     -1
# 1     1749    2  1749.123    104.3   -1.0     -1
# 2     1749    3  1749.204    116.7   -1.0     -1
# 3     1749    4  1749.288     92.8   -1.0     -1
# 4     1749    5  1749.371    141.7   -1.0     -1
# 5     1749    6  1749.455    139.2   -1.0     -1
# 6     1749    7  1749.538    158.0   -1.0     -1
# 7     1749    8  1749.623    110.5   -1.0     -1
# 8     1749    9  1749.707    126.5   -1.0     -1
# 9     1749   10  1749.790    125.8   -1.0     -1
# 10    1749   11  1749.874    264.3   -1.0     -1
# 11    1749   12  1749.958    142.0   -1.0     -1
# 12    1750    1  1750.042    122.2   -1.0     -1
# 13    1750    2  1750.123    126.5   -1.0     -1
# 14    1750    3  1750.204    148.7   -1.0     -1
# 15    1750    4  1750.288    147.2   -1.0     -1
# 16    1750    5  1750.371    150.0   -1.0     -1
# 17    1750    6  1750.455    166.7   -1.0     -1
# ...

# %%
#grafica de manchas contra fecha en decimales
import matplotlib.pyplot as mplt


df[u'manchas'] = df[u'manchas'].astype(float).interpolate(method='spline', order=2)

fig = mplt.gcf()
fig.set_size_inches(13.5, 7.5)

mplt.plot(df[u'añodec'], df[u'manchas'])

mplt.ylabel('Manchas solares')
mplt.xlabel('Fecha con meses en decimales')
mplt.legend(fancybox=True, shadow=True)
mplt.grid(True)

# %%
import matplotlib.pyplot as mplt
fig = mplt.gcf()
fig.set_size_inches(13.5, 7.5)

df[u'manchas'] = df[u'manchas'].astype(float).interpolate(method='spline', order=2)

import numpy as np
from scipy.fftpack import rfft
# Number of samplepoints
N = 3212
# sample spacing
T = 1.0/132
x = df[u'añodec']
#eliminando la suma
y = df[u'manchas']
yf = rfft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N * np.abs(yf[0:N/2]))
plt.xlim(-0.1,3)
plt.ylim(0,180)
plt.grid()
plt.show()
# Out:
# /opt/anaconda/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:21: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
#Obtener valores de la funcion furrier por orden, en este caso de menor a mayor

np.sort(2.0/N * np.abs(yf[0:N/2]))
# Out:
# /opt/anaconda/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   app.launch_new_instance()
# array([  6.33186652e-04,   1.09454314e-03,   1.76149269e-03,
#          2.82971125e-03,   3.44196265e-03,   3.74302704e-03,
#          3.87569379e-03,   4.47643687e-03,   4.99332582e-03,
#          5.92767024e-03,   6.09754864e-03,   6.80613923e-03,
#          8.26190886e-03,   8.29803568e-03,   8.52898789e-03,
#          8.77784416e-03,   9.59248617e-03,   1.14420149e-02,
#          1.15095294e-02,   1.26316338e-02,   1.32533295e-02,
#          1.39447410e-02,   1.39455191e-02,   1.41643618e-02,
#          1.43961418e-02,   1.44087386e-02,   1.56364141e-02,
#          1.57929561e-02,   1.59409558e-02,   1.68225703e-02,
#          1.82458526e-02,   1.89135978e-02,   1.90265156e-02,
#          1.97957820e-02,   1.99503874e-02,   2.02048748e-02,
# ...

# %%
#coeficientes de amplitud
A0 = 1.65898755e+02/2
A1 = 3.37184643e+01
A2 = 3.01312952e+01
A3 = 2.60238413e+01
A4 = 2.25150056e+01
A5 = 2.15183589e+01
A6 = 2.02882331e+01
A7 = 1.45679271e+01
A8 = 1.52142842e+01
A9 = 1.66931548e+01
A10 = 1.86400334e+01

# %%
#hacer arreglo de n y amplitudes
arr1 = xf
arr2 = 2.0/N*np.abs(yf[0:N/2])

arr3 = np.column_stack((arr2, arr1))
# Out:
# /opt/anaconda/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   from ipykernel import kernelapp as app

# %%
#ordenar n por la amplitud
arr3[np.lexsort(np.transpose(arr3)[::-1])]
# Out:
# array([[  6.33186652e-04,   3.65158879e+01],
#        [  1.09454314e-03,   3.41719626e+01],
#        [  1.76149269e-03,   2.36859813e+01],
#        [  2.82971125e-03,   1.40224299e+01],
#        [  3.44196265e-03,   4.23140187e+01],
#        [  3.74302704e-03,   1.09383178e+01],
#        [  3.87569379e-03,   9.91028037e+00],
#        [  4.47643687e-03,   5.77757009e+01],
#        [  4.99332582e-03,   3.96411215e+01],
#        [  5.92767024e-03,   4.50691589e+01],
#        [  6.09754864e-03,   5.39102804e+01],
#        [  6.80613923e-03,   3.37607477e+01],
#        [  8.26190886e-03,   4.06280374e+01],
#        [  8.29803568e-03,   4.74130841e+01],
#        [  8.52898789e-03,   6.36971963e+01],
#        [  8.77784416e-03,   4.96336449e+01],
#        [  9.59248617e-03,   3.03065421e+01],
#        [  1.14420149e-02,   6.55065421e+01],
#        [  1.15095294e-02,   6.57943925e+01],
#        [  1.26316338e-02,   3.80785047e+01],
#        [  1.32533295e-02,   5.93794393e+01],
# ...

# %%
#valores de n
n1 = 1.93271028e+00
n2 = 2.01495327e+00
n3 = 2.22056075e+00
n4 = 2.46728972e-01
n5 = 1.97383178e+00
n6 = 1.89158879e+00
n7 = 2.05607477e+00
n8 = 2.17943925e+00
n9 = 2.87850467e-01
n10 = 2.71401869e+00
A25 = 8.51428545e+00
n25 = 1.02803738e+00
A24 = 8.75195730e+00  
n24 = 2.63177570e+00
A23 = 8.87041427e+00  
n23 = 2.30280374e+00
A22 = 9.02841767e+00  
n22 = 1.60373832e+00
A21= 9.19380164e+00
n21 = 1.48037383e+00 
A20 = 9.47297411e+00  
n20 = 1.76822430e+00
A19 = 9.56882154e+00  
n19 = 8.22429907e-02
A18 = 1.01492101e+01   
n18 = 1.85046729e+00
A17= 1.01682932e+01 
n17=4.02990654e+00
A16= 1.12159511e+01
n16=4.11214953e-01
A15 = 1.13405256e+01  
n15 = 2.38504673e+00
A14= 1.14610120e+01  
n14= 1.64485981e-01
A13= 1.23498412e+01 
n13 = 2.09719626e+00
A12= 1.26781287e+01
n12 = 1.52149533e+00
A11= 1.28866940e+01
n11 = 2.46728972e+00

# %%
#definir periodos
T1 = 132/n1
T2 = 132/n2
T3 = 132/n3
T4 = 132/n4
T5 = 132/n5
T6 = 132/n6
T7 = 132/n7
T8 = 132/n8
T9 = 132/n9
T10 = 132/n10

# %%
#valores
A20 = 9.47297411e+00  
n20 = 1.76822430e+00
A19 = 9.56882154e+00  
n19 = 8.22429907e-02
A18 = 1.01492101e+01   
n18 = 1.85046729e+00
A17= 1.01682932e+01 
n17=4.02990654e+00
A16= 1.12159511e+01
n16=4.11214953e-01
A15 = 1.13405256e+01  
n15 = 2.38504673e+00
A14= 1.14610120e+01  
n14= 1.64485981e-01
A13= 1.23498412e+01 
n13 = 2.09719626e+00
A12= 1.26781287e+01
n12 = 1.52149533e+00
A11= 1.28866940e+01
n11 = 2.46728972e+00
A25 = 8.51428545e+00
n25 = 1.02803738e+00
A24 = 8.75195730e+00  
n24 = 2.63177570e+00
A23 = 8.87041427e+00  
n23 = 2.30280374e+00
A22 = 9.02841767e+00  
n22 = 1.60373832e+00
A21= 9.19380164e+00
n21 = 1.48037383e+00
#coeficientes de amplitud
A0 = 1.65898755e+02/2
A1 = 3.37184643e+01
A2 = 3.01312952e+01
A3 = 2.60238413e+01
A4 = 2.25150056e+01
A5 = 2.15183589e+01
A6 = 2.02882331e+01
A7 = 1.45679271e+01
A8 = 1.52142842e+01
A9 = 1.66931548e+01
A10 = 1.86400334e+01
#definir periodos
T1 = 132/n1
T2 = 132/n2
T3 = 132/n3
T4 = 132/n4
T5 = 132/n5
T6 = 132/n6
T7 = 132/n7
T8 = 132/n8
T9 = 132/n9
T10 = 132/n10
T11 = 132/n11
T12 = 132/n12
T13 = 132/n13
T14 = 132/n14
T15 = 132/n15
T16 = 132/n16
T17 = 132/n17
T18 = 132/n18
T19 = 132/n19
T20 = 132/n20
T21 = 132/n21
T22 = 132/n22
T23 = 132/n23
T24 = 132/n24
T25 = 132/n25

def f(t):
 return A0 + (A1)*np.sin(2*np.pi*t/T1)  + (A2)*np.sin(2*np.pi*t/T2) + (A3)*np.sin(2*np.pi*t/T3) + (A4)*np.sin(2*np.pi*t/T4) + (A5)*np.sin(2*np.pi*t/T5) + (A6)*np.sin(2*np.pi*t/T6) + (A7)*np.sin(2*np.pi*t/T7) + (A8)*np.sin(2*np.pi*t/T8) + (A9)*np.sin(2*np.pi*t/T9) + (A10)*np.sin(2*np.pi*t/T10)  + (A11)*np.sin(2*np.pi*t/T11) + (A12)*np.sin(2*np.pi*t/T12) + (A13)*np.sin(2*np.pi*t/T13) + (A14)*np.sin(2*np.pi*t/T14) + (A15)*np.sin(2*np.pi*t/T15) + (A16)*np.sin(2*np.pi*t/T16)  + (A17)*np.sin(2*np.pi*t/T17)  + (A18)*np.sin(2*np.pi*t/T18)  + (A19)*np.sin(2*np.pi*t/T19)  + (A20)*np.sin(2*np.pi*t/T20) + (A21)*np.sin(2*np.pi*t/T21) + (A22)*np.sin(2*np.pi*t/T22) + (A23)*np.sin(2*np.pi*t/T23) + (A24)*np.sin(2*np.pi*t/T24) + (A25)*np.sin(2*np.pi*t/T25) 

#interpolar la funcion

fig = mplt.gcf()
fig.set_size_inches(13.5, 7.5)

mplt.plot(df[u'añodec'], f(df[u'añodec']), c='black', label='Ajuste Fourier')
mplt.plot(df[u'añodec'], df['manchas'], c='red', label='Datos NASA')

mplt.xlim([1750, 2017])
mplt.ylim([-5, 400])

mplt.ylabel('Manchas solares')
mplt.xlabel('Fecha en decimales')
mplt.legend(fancybox=True, shadow=True)
mplt.grid(True)

# %%
#coeficientes de amplitud
A0 = 1.65898755e+02/2
A1 = 3.37184643e+01
A2 = 3.01312952e+01
A3 = 2.60238413e+01
A4 = 2.25150056e+01
A5 = 2.15183589e+01
A6 = 2.02882331e+01
A7 = 1.45679271e+01
A8 = 1.52142842e+01
A9 = 1.66931548e+01
A10 = 1.86400334e+01
#valores n
n1 = 1.93271028e+00
n2 = 2.01495327e+00
n3 = 2.22056075e+00
n4 = 2.46728972e-01
n5 = 1.97383178e+00
n6 = 1.89158879e+00
n7 = 2.05607477e+00
n8 = 2.17943925e+00
n9 = 2.87850467e-01
n10 = 2.71401869e+00
#definir periodos
T1 = 132/n1
T2 = 132/n2
T3 = 132/n3
T4 = 132/n4
T5 = 132/n5
T6 = 132/n6
T7 = 132/n7
T8 = 132/n8
T9 = 132/n9


#periodo principal (por una definicion enel codigo se debe multiplicar por 2)
t1 = 2*T1/12
t1
# Out:
# 11.382978725605993

# %%
t2 = 2*T2/12
t2
# Out:
# 10.918367352509371

# %%
t3 = 2*T3/12
t3
# Out:
# 9.907407396982945

# %%
#periodo promedio (3 principales periodos)
a = [t1, t2, t3]
np.mean(a)
# Out:
# 10.736251158366104

# %%
#ignore el periodo T4 por que salia de casi 100años
t4 = 2*T5/12
t4
# Out:
# 11.145833309057371

# %%
t5 = 2*T6/12
t5
# Out:
# 11.630434752153507

# %%
t6 =  2*T7/12
t6
# Out:
# 10.699999981031818

# %%
t7 =  2*T8/12
t7
# Out:
# 10.094339633463056

# %%
#periodo promedio (7 principales periodos)
a = [t1, t2, t3,t4,t5,t6,t7]
np.mean(a)
# Out:
# 10.825623021543437
