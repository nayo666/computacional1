# %%
import pandas as pd

import numpy as np

import matplotlib as plt

# %matplotlib inline

# %%
df = pd.read_csv ("/home/noxd/computacional/a6/mona.csv")

# %%
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Date Time       0
#  Water Level    0
#  Sigma          1
#  O              0
#  F              0
#  R              0
#  L              0
#  Quality        0
# dtype: int64

# %%
df_clean = df.dropna()
len(df)
# Out:
# 7440

# %%
df_short=df.drop(df.columns[[2,3,4,5,6,7]],axis=1)

# %%
df_short.columns
# Out:
# Index([u'Date Time', u' Water Level'], dtype='object')

# %%
import scipy
a = df_short[u' Water Level'].astype(float).interpolate(method='spline', order=2)

# %%
df_short
# Out:
#              Date Time   Water Level
# 0     2016-12-01 00:00         0.568
# 1     2016-12-01 00:06         0.623
# 2     2016-12-01 00:12         0.515
# 3     2016-12-01 00:18         0.614
# 4     2016-12-01 00:24         0.420
# 5     2016-12-01 00:30         0.495
# 6     2016-12-01 00:36         0.607
# 7     2016-12-01 00:42         0.486
# 8     2016-12-01 00:48         0.495
# 9     2016-12-01 00:54         0.476
# 10    2016-12-01 01:00         0.466
# 11    2016-12-01 01:06         0.538
# 12    2016-12-01 01:12         0.472
# 13    2016-12-01 01:18         0.440
# 14    2016-12-01 01:24         0.430
# 15    2016-12-01 01:30         0.384
# 16    2016-12-01 01:36         0.453
# 17    2016-12-01 01:42         0.394
# 18    2016-12-01 01:48         0.453
# 19    2016-12-01 01:54         0.476
# 20    2016-12-01 02:00         0.486
# 21    2016-12-01 02:06         0.410
# 22    2016-12-01 02:12         0.449
# 23    2016-12-01 02:18         0.499
# ...

# %%
df_short['month']=pd.DatetimeIndex(df_short[u'Date Time']).month

# %%
df_dic=df_short.loc[df_short[u'month'] == 12]

# %%
df_dic
# Out:
#              Date Time   Water Level  month
# 0     2016-12-01 00:00         0.568     12
# 1     2016-12-01 00:06         0.623     12
# 2     2016-12-01 00:12         0.515     12
# 3     2016-12-01 00:18         0.614     12
# 4     2016-12-01 00:24         0.420     12
# 5     2016-12-01 00:30         0.495     12
# 6     2016-12-01 00:36         0.607     12
# 7     2016-12-01 00:42         0.486     12
# 8     2016-12-01 00:48         0.495     12
# 9     2016-12-01 00:54         0.476     12
# 10    2016-12-01 01:00         0.466     12
# 11    2016-12-01 01:06         0.538     12
# 12    2016-12-01 01:12         0.472     12
# 13    2016-12-01 01:18         0.440     12
# 14    2016-12-01 01:24         0.430     12
# 15    2016-12-01 01:30         0.384     12
# 16    2016-12-01 01:36         0.453     12
# 17    2016-12-01 01:42         0.394     12
# 18    2016-12-01 01:48         0.453     12
# 19    2016-12-01 01:54         0.476     12
# ...

# %%
# rango de días
time_range = pd.date_range('2016-12-01 00:00','2016-12-31 23:54', freq='6T')


#rangos de tiempo
mins = time_range.minute
hours = time_range.hour
days = time_range.day


#calcular el numero de cada 6 minutos
time_serie =  (days-1)*24*60+ hours*60 + mins
time_serie
# Out:
# array([    0,     6,    12, ..., 44622, 44628, 44634], dtype=int32)

# %%
df_dic['6mins']=time_serie

# %%
del df_dic[u'month']

# %%
del df_dic[u'Date Time']

# %%
df_dic
# Out:
#        Water Level  6mins
# 0            0.568      0
# 1            0.623      6
# 2            0.515     12
# 3            0.614     18
# 4            0.420     24
# 5            0.495     30
# 6            0.607     36
# 7            0.486     42
# 8            0.495     48
# 9            0.476     54
# 10           0.466     60
# 11           0.538     66
# 12           0.472     72
# 13           0.440     78
# 14           0.430     84
# 15           0.384     90
# 16           0.453     96
# 17           0.394    102
# 18           0.453    108
# 19           0.476    114
# 20           0.486    120
# 21           0.410    126
# 22           0.449    132
# 23           0.499    138
# 24           0.312    144
# 25           0.443    150
# 26           0.371    156
# 27           0.430    162
# 28           0.390    168
# 29           0.312    174
# ...            ...    ...
# 7410         0.883  44460
# 7411         0.912  44466
# 7412         0.827  44472
# ...

# %%
import matplotlib.pyplot as mplt
fig = mplt.gcf()
fig.set_size_inches(13.5, 7.5)



import numpy as np
from scipy.fftpack import rfft
# Number of samplepoints
N = 7440
# sample spacing
T = 1.0 / 372
x = df_dic[u'6mins']
#eliminando la suma
y = df_dic[u' Water Level']
yf = rfft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N * np.abs(yf[0:N/2]))
plt.xlim(-5,80)
plt.ylim(0,1.5)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as mplt
fig = mplt.gcf()
fig.set_size_inches(13.5, 7.5)

import numpy as np
from scipy.fftpack import rfft
# Number of samplepoints
N = 7440
# sample spacing
T = 1.0 / 372
x = df_dic[u'6mins']
#eliminando la suma
y = df_dic[u' Water Level']
yf = rfft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N * np.abs(yf[0:N/2]))
plt.xlim(-0.1,15)
plt.ylim(0,0.3)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as mplt
fig = mplt.gcf()
fig.set_size_inches(13.5, 7.5)

import numpy as np
from scipy.fftpack import rfft
# Number of samplepoints
N = 7440
# sample spacing
T = 1.0 / 372
x = df_dic[u'6mins']
#eliminando la suma
y = df_dic[u' Water Level']
yf = rfft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N * np.abs(yf[0:N/2]))
plt.xlim(-0.1,15)
plt.ylim(0,0.05)
plt.grid()
plt.show()

# %%
#Obtener valores de la funcion furrier por orden, en este caso de menor a mayor
#como el arreglo tiene muchos datos se le agrega una opcion para que ponga todos los valores
np.set_printoptions(threshold='nan')
temp =  2.0/N * np.abs(yf[0:N/2])
 
temp.sort()
 
temp
# Out:
# array([  2.46224208e-07,   2.48495702e-07,   4.38981217e-07,
#          5.85040474e-07,   9.78546934e-07,   9.99330211e-07,
#          1.14532928e-06,   1.18076600e-06,   1.48063942e-06,
#          1.64024717e-06,   1.64241434e-06,   1.66580408e-06,
#          1.71619277e-06,   2.03580365e-06,   2.83985425e-06,
#          2.89391833e-06,   3.55047216e-06,   3.67257512e-06,
#          3.74866199e-06,   4.65172899e-06,   4.77481582e-06,
#          4.79369829e-06,   4.94177633e-06,   5.43212135e-06,
#          5.60481187e-06,   5.79461559e-06,   6.00280673e-06,
#          6.99186876e-06,   7.03507532e-06,   7.20235428e-06,
#          7.41492339e-06,   7.50429802e-06,   7.77464084e-06,
#          7.90787597e-06,   7.99718080e-06,   8.33033594e-06,
#          8.74831471e-06,   8.88288426e-06,   9.24069479e-06,
#          9.26684405e-06,   9.38757916e-06,   9.43123877e-06,
#          9.56627381e-06,   9.93345972e-06,   1.00624008e-05,
# ...
