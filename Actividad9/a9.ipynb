# %%
pops = simulate(model=logistic_map, num_gens=100, rate_min=0, rate_max=4, num_rates=1000, num_discard=100)
bifurcation_plot(pops, color='red', xlabel='Tasa de Crecimiento', ylabel='Población', title='Diagrama de Bifurcación')

# %%
pops = simulate(model=logistic_map, num_gens=100, rate_min=3.4, rate_max=4, num_rates=1000, num_discard=100)
bifurcation_plot(pops, color='g', xlabel='Tasa de Crecimiento', ylabel='Población', title='Diagrama de Bifurcación',xmin=3.4, xmax=4)

# %%
from pynamical import phase_diagram
pops = simulate(model=logistic_map, num_gens=4000, rate_min=3.6, rate_max=4.0, num_rates=50, num_discard=100)
phase_diagram(pops, xmin=0.25, xmax=0.75, ymin=0.8, ymax=1.01, size=7, color='inferno', xlabel='Población (t)', ylabel='Población (t+1)', title='Diagrama de Fase de Mapa Logístico')

# %%
from pynamical import cubic_map, phase_diagram_3d
pops = simulate(model=cubic_map, num_gens=3000, rate_min=3.5, num_rates=30, num_discard=100)
phase_diagram_3d(pops, xmin=-1, xmax=1, ymin=-1, ymax=1, zmin=-1, zmax=1, alpha=0.2, color='plasma', azim=330, xlabel='Población (t)', ylabel='Población (t + 1)', zlabel='Población (t + 2)', title='Mapa de Atractor Cúbico')

# %%
from pynamical import cubic_map, phase_diagram_3d
pops = simulate(model=cubic_map, num_gens=3000, rate_min=3.5, num_rates=30, num_discard=100)
phase_diagram_3d(pops, xmin=-1, xmax=1, ymin=-1, ymax=1, zmin=-1, zmax=1, alpha=0.2, color='plasma', azim=230, xlabel='Población (t)', ylabel='Población (t + 1)', zlabel='Población (t + 2)', title='Mapa de Atractor Cúbico')

# %%
# phase diagram: each chaotic growth rate has its own strange attractor curling through state space
pops = simulate(num_gens=2000, rate_min=3.6, rate_max=4.0, num_rates=50)
phase_diagram_3d(pops, title='Mapa de Atractor Logístico, r=3.6 a r=4.0', alpha=0.1, color='magma', color_reverse=False, 
                 elev=7, azim=320, filename='3d-logistic-map-attractor-2', xlabel='Población (t)', ylabel='Población (t + 1)', zlabel='Población (t + 2)')

# %%
# phase diagram: each chaotic growth rate has its own strange attractor curling through state space
pops = simulate(num_gens=2000, rate_min=3.6, rate_max=4.0, num_rates=50)
phase_diagram_3d(pops, title='Mapa de Atractor Logístico, r=3.6 a r=4.0', alpha=0.1, color='magma', color_reverse=False, 
                 elev=7, azim=230, filename='3d-logistic-map-attractor-2', xlabel='Población (t)', ylabel='Población (t + 1)', zlabel='Población (t + 2)')
